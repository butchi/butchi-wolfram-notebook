# %% [markdown]
# # graha-fractal-4-experment-2021-10-27.nb
#
# from graha-fractal-9.nb
#
# created at 2021-10-27

# %%
ifs[pLi_] := Flatten[Table[{(1/2) pLi + 2 E^((2 \[Pi] I n)/4)} // N, {n, 0, 3}]];

init = {0};

g = Graphics[
    Table[
        Disk[ReIm[#], 1/4 (1/2)^n // N] & /@ Nest[ifs, init, n],
        {n, 0, 7}
    ]
]

(* Export["graha-fractal-four.pdf", g] *)
# Out:
# -Graphics-
