# %% [markdown]
# # Square root of 1
#
# 自己同形数 (Automorphic number)
#
# created-at: 2024-02-17

# %% [markdown]
# a = ...0625: [A018247 - OEIS](https://oeis.org/A018247)
#
# b = ...9376: [A018248 - OEIS](https://oeis.org/A018248)
#
# $a^2$ = a
#
# $b^2$ = b
#
# a + b = ...0001
#
# a b = ...0000
#
#
# c = ...1249: [A091661 - OEIS](https://oeis.org/A091661)
#
# d = ...8751: [A063006 - OEIS](https://oeis.org/A063006)
#
# $c^3$ = c
#
# $d^3$ = d
#
# c + d = ...0001
#
# c d = ...9999
#
# b + c = a
#
#
# e = ...9375: [A091663 - OEIS](https://oeis.org/A091663)
#
# f = ...0624: [A091664 - OEIS](https://oeis.org/A091664)
#
# $e^3$ = e
#
# $f^3$ = f
#
# e + f = ...9999
#
# e f = ...0000
#
# a + e = ...0000
#
# b + f = ...0000 // A091663では1と記載
#
# d + f = e
#
# a + f = c
#
# a = f + 1
#
# b = e + 1
#
# c d = ...9999
#
# a f = ...0000 // A091663では-1と記載
#
# r = ...6342: [A120817 - OEIS](https://oeis.org/A120817)
#
# s = ...3568: [A120818 - OEIS](https://oeis.org/A120818)

# %%
n = 32;

# %%
a = PowerMod[5, 2^n, 10^n]
b = PowerMod[16, 5^n, 10^n]
# Out:
# 4106619977392256259918212890625
# 95893380022607743740081787109376

# %%
Select[Range[9999], Mod[#^2, 10000] == # &]
# Out:
# {1, 625, 9376}

# %%
Mod[a^2, 10^n]
Mod[b^2, 10^n]
# Out:
# 4106619977392256259918212890625
# 95893380022607743740081787109376

# %%
Mod[a + b, 10^n]
Mod[a b, 10^n]
# Out:
# 1
# 0

# %%
c = 2 a - 1
d = 2 b - 1
# Out:
# 8213239954784512519836425781249
# 191786760045215487480163574218751

# %%
e = 10^n - a
f = 10^n - b
# Out:
# 95893380022607743740081787109375
# 4106619977392256259918212890624

# %%
Select[Range[9999], Mod[#^3, 10000] == # && Mod[#^2, 10000] != # &]
# Out:
# {624, 1249, 3751, 4375, 4999, 5001, 5625, 6249, 8751, 9375, 9999}

# %%
Select[Range[9999], Mod[#^3, 1250] == # && Mod[#^2, 1250] != # &]
# Out:
# {624, 1249}

# %%
Select[Range[9999], Mod[#^5, 1250] == # && Mod[#^2, 1250] != # &]
# Out:
# {182, 443, 624, 807, 1068, 1249}

# %%
r = PowerMod[2, 5^n, 10^n]
s = 10^n - r
# Out:
# 65530407839804103263499879186432
# 34469592160195896736500120813568

# %% [markdown]
# xのx乗根？ xをx + 1乗したら元に戻る

# %%
PowerMod[r, r + 1, 10^n]
PowerMod[s, s + 1, 10^n]
# Out:
# 65530407839804103263499879186432
# 34469592160195896736500120813568

# %%
(* すでに求まっているけれどせっかく組んだので残しておく *)

FromDigits[Reverse[#]] & /@ With[{len = 25}, 
    Table[
        Nest[
            If[Length[#] > 0, 
            With[{dLen = Length[#] + 1}, 
                SelectFirst[Table[Join[#, {digit}], {digit, 0, 9}], 
                Function[li, 
                    With[{x = FromDigits[Reverse[li]]}, 
                    PowerMod[x, x + 1, 10^dLen] == x && 
                    PowerMod[x, 2, 10^dLen] != x && 
                    PowerMod[x, 3, 10^dLen] != x]
                ], Null]
            ], Nothing] &, {d}, 
        len - 1],
    {d, 0, 9}]
]
# Out:
# {7839804103263499879186432, 2160195896736500120813568}
