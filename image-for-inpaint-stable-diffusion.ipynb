# %%
img = ImageResize[ImagePad[ResourceData["Sample Image: Happy Family in Red"], {{0, 0}, {68, 69}}, White], 512]
# Out:
# -Image-

# %%
FindFaces[img]
# Out:
# {Rectangle[{233.5, 263.5}, {290.5, 344.5}], Rectangle[{419.5, 273.5}, {471.5, 340.5}],
#
# >   Rectangle[{48.5, 262.5}, {99.5, 333.5}], Rectangle[{344.5, 255.5}, {388.5, 304.5}],
#
# >   Rectangle[{134.5, 228.5}, {181.5, 282.5}]}

# %%
gMask = Graphics[{White, FindFaces[img]}, ImageSize -> {512, 512}, Background -> Black]
# Out:
# -Graphics-

# %%
ImageDimensions[gMask]
# Out:
# {683, 683}

# %%
HighlightImage[img, {{"Blur", 3}, FindFaces[#, "BoundingBox"] &}]
# Out:
# -Graphics-

# %%
Inpaint[HighlightImage[img, {{"Blur", 3}, FindFaces[#, "BoundingBox"] &}], gMask]
# Out:
# -Image-

# %%
Export["image-for-inpaint-stable-diffusion/happy-family-in-red-face-blur-3.png", HighlightImage[img, {{"Blur", 3}, FindFaces[#, "BoundingBox"] &}], ImageSize -> {512, 512}]
# Out:
# image-for-inpaint-stable-diffusion/happy-family-in-red-face-blur-3.png
