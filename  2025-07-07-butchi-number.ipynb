# %%
Grid[Table[(2 Cos[x]^2)^m (2 Sin[x]^2)^n, {n, 0, 6}, {m, 0, 6}]]
# Out:
#                       2                      4                      6
# 1             2 Cos[x]               4 Cos[x]               8 Cos[x]
#
#               8                       10                       12
# >    16 Cos[x]               32 Cos[x]                64 Cos[x]
#
#         2             2       2              4       2               6       2
# 2 Sin[x]      4 Cos[x]  Sin[x]       8 Cos[x]  Sin[x]       16 Cos[x]  Sin[x]
#
#               8       2               10       2                12       2
# >    32 Cos[x]  Sin[x]       64 Cos[x]   Sin[x]       128 Cos[x]   Sin[x]
#
#         4             2       4               4       4              6       4
# 4 Sin[x]      8 Cos[x]  Sin[x]       16 Cos[x]  Sin[x]      32 Cos[x]  Sin[x]
#
#               8       4                10       4               12       4
# >    64 Cos[x]  Sin[x]       128 Cos[x]   Sin[x]      256 Cos[x]   Sin[x]
#
#         6              2       6              4       6              6       6
# ...

# %%
Grid[Table[(Sqrt[2] Cos[x])^m (Sqrt[2] Sin[x])^n, {n, 0, 3}, {m, 0, 3}]]
# Out:
#                                                        2
# 1                   Sqrt[2] Cos[x]             2 Cos[x]
#
#                      3
# >    2 Sqrt[2] Cos[x]
#
#                                                                2
# Sqrt[2] Sin[x]      2 Cos[x] Sin[x]            2 Sqrt[2] Cos[x]  Sin[x]
#
#              3
# >    4 Cos[x]  Sin[x]
#
#         2                                  2           2       2
# 2 Sin[x]            2 Sqrt[2] Cos[x] Sin[x]    4 Cos[x]  Sin[x]            4 Sqrt[2]
#
#            3       2
# >    Cos[x]  Sin[x]
#
#                 3                  3                           2       3
# 2 Sqrt[2] Sin[x]    4 Cos[x] Sin[x]            4 Sqrt[2] Cos[x]  Sin[x]
#
#              3       3
# >    8 Cos[x]  Sin[x]

# %%
Solve[p^2 + q^2 == 1, p]
# Out:
#                    2                     2
# {{p -> -Sqrt[-1 - q ]}, {p -> Sqrt[-1 - q ]}}

# %%
(I Cos[x])^2 + (I Sin[x])^2 // FullSimplify
# Out:
# -1

# %%
Grid[Table[(I Cos[x])^m (I Sin[x])^n, {n, 0, 3}, {m, 0, 3}]]
# Out:
#                                         2                     3
# 1            I Cos[x]            -Cos[x]             -I Cos[x]
#
#                                           2                3
# I Sin[x]     -(Cos[x] Sin[x])    -I Cos[x]  Sin[x]   Cos[x]  Sin[x]
#
#        2                     2         2       2             3       2
# -Sin[x]      -I Cos[x] Sin[x]    Cos[x]  Sin[x]      I Cos[x]  Sin[x]
#
#          3                3              2       3           3       3
# -I Sin[x]    Cos[x] Sin[x]       I Cos[x]  Sin[x]    -(Cos[x]  Sin[x] )

# %%
Grid[Table[(2 Cos[x]^2)^m (2 Sin[x]^2)^n, {n, 0, 3}, {m, 0, 3}]]
# Out:
#                     2                    4                    6
# 1           2 Cos[x]             4 Cos[x]             8 Cos[x]
#
#         2           2       2            4       2             6       2
# 2 Sin[x]    4 Cos[x]  Sin[x]     8 Cos[x]  Sin[x]     16 Cos[x]  Sin[x]
#
#         4           2       4             4       4            6       4
# 4 Sin[x]    8 Cos[x]  Sin[x]     16 Cos[x]  Sin[x]    32 Cos[x]  Sin[x]
#
#         6            2       6            4       6            6       6
# 8 Sin[x]    16 Cos[x]  Sin[x]    32 Cos[x]  Sin[x]    64 Cos[x]  Sin[x]

# %%
8 Cos[x]^6 + 8 Sin[x]^6 + 16 Cos[x]^6 Sin[x]^2 + 16 Cos[x]^2 Sin[x]^6 + 32 Cos[x]^6 Sin[x]^4 + 32 Cos[x]^4 Sin[x]^6 + 8 Cos[x]^4 Sin[x]^2 + 8 Cos[x]^2 Sin[x]^4 // FullSimplify
# Out:
# 8
