# %%
Graph[Table[i - 1 -> Mod[2(i - 1), 9], {i, 9}], VertexLabels -> "Name"]
# Out:
# Graph[<9>, <9>]

# %%
Graph[Table[i - 1 -> Mod[2(i - 1), 15], {i, 15}], VertexLabels -> "Name"]
# Out:
# Graph[<15>, <15>]

# %%
Grid[Table[Mod[4^(m - 1) 3^(n - 1), 15], {m, 6}, {n, 3}]]
# Out:
# 1   3    9
#
# 4   12   6
#
# 1   3    9
#
# 4   12   6
#
# 1   3    9
#
# 4   12   6

# %%
Graph[Table[i - 1 -> Mod[2(i - 1), 99], {i, 99}], VertexLabels -> "Name"]
# Out:
# Graph[<99>, <99>]

# %%
Graph[Table[i - 1 -> Mod[3 (i - 1), 99], {i, 99}], VertexLabels -> "Name"]
# Out:
# Graph[<99>, <99>]

# %%
Graph[Join[Table[i - 1 -> Mod[2 (i - 1), 99], {i, 99}], Table[i - 1 -> Mod[3 (i - 1), 99], {i, 99}]], VertexLabels -> "Name"]
# Out:
# Graph[<99>, <198>]

# %%
Graph[Join[Table[i - 1 -> Mod[2 (i - 1), 9], {i, 9}], Table[i - 1 -> Mod[3 (i - 1), 9], {i, 9}]], VertexLabels -> "Name"]
# Out:
# Graph[<9>, <18>]

# %%
Graph[Join[Table[i - 1 -> Mod[2 (i - 1), 99], {i, 99}], Table[i - 1 -> Mod[5 (i - 1), 99], {i, 99}]], VertexLabels -> "Name"]
# Out:
# Graph[<99>, <198>]

# %%
ConnectedComponents[Graph[Table[i - 1 -> Mod[2 (i - 1), 9], {i, 9}], VertexLabels -> "Name"]]
# Out:
# {{0}, {1, 2, 4, 8, 5, 7}, {3, 6}}

# %%
ConnectedComponents[Graph[Table[i - 1 -> Mod[2 (i - 1), 99], {i, 99}], VertexLabels -> "Name"]]
# Out:
# {{0}, {1, 2, 4, 8, 16, 32, 17, 34, 25, 50, 29, 58, 31, 62, 64, 68, 35, 70, 37, 74, 41,
#
# >    82, 49, 98, 65, 67, 83, 91, 95, 97}, {3, 6, 12, 24, 48, 96, 51, 75, 87, 93},
#
# >   {5, 10, 7, 14, 20, 13, 26, 28, 19, 38, 40, 23, 46, 52, 56, 76, 80, 43, 86, 92, 47,
#
# >    94, 53, 59, 61, 71, 73, 79, 85, 89}, {9, 18, 36, 27, 54, 72, 45, 90, 63, 81},
#
# >   {11, 22, 44, 88, 55, 77}, {15, 30, 21, 42, 60, 39, 78, 84, 57, 69}, {33, 66}}

# %%
ConnectedComponents[Graph[Table[i - 1 -> Mod[3 (i - 1), 99], {i, 99}], VertexLabels -> "Name"]]
# Out:
# {{0}, {9, 27, 36, 45, 81}, {3}, {1}, {18, 54, 63, 72, 90}, {6}, {2}, {12}, {4}, {15},
#
# >   {5}, {21}, {7}, {24}, {8}, {30}, {10}, {33}, {11}, {39}, {13}, {42}, {14}, {48},
#
# >   {16}, {51}, {17}, {57}, {19}, {60}, {20}, {66}, {22}, {69}, {23}, {75}, {25}, {78},
#
# >   {26}, {84}, {28}, {87}, {29}, {93}, {31}, {96}, {32}, {34}, {35}, {37}, {38}, {40},
#
# >   {41}, {43}, {44}, {46}, {47}, {49}, {50}, {52}, {53}, {55}, {56}, {58}, {59}, {61},
#
# >   {62}, {64}, {65}, {67}, {68}, {70}, {71}, {73}, {74}, {76}, {77}, {79}, {80}, {82},
#
# >   {83}, {85}, {86}, {88}, {89}, {91}, {92}, {94}, {95}, {97}, {98}}

# %%
ConnectedComponents[Graph[Table[i - 1 -> Mod[5 (i - 1), 99], {i, 99}], VertexLabels -> "Name"]]
# Out:
# {{0}, {1, 5, 4, 20, 25, 14, 70, 16, 80, 23, 26, 31, 56, 34, 71, 37, 86, 38, 91, 47, 49,
#
# >    53, 67, 82, 58, 92, 59, 97, 64, 89},
#
# >   {2, 10, 7, 35, 8, 40, 50, 13, 65, 17, 85, 19, 95, 28, 41, 29, 46, 32, 61, 76, 43,
#
# >    52, 62, 68, 73, 74, 83, 79, 98, 94}, {3, 15, 12, 60, 75, 42, 48, 69, 78, 93},
#
# >   {6, 30, 21, 24, 51, 39, 96, 57, 87, 84}, {9, 45, 27, 36, 81},
#
# >   {11, 55, 22, 44, 77, 88}, {18, 90, 54, 72, 63}, {33, 66}}

# %%
Grid[Table[a^m * b^n, {m, 0, 6}, {n, 0, 6}] /.  {a -> 2, b -> 5}]
# Out:
# 1    5     25     125    625     3125     15625
#
# 2    10    50     250    1250    6250     31250
#
# 4    20    100    500    2500    12500    62500
#
# 8    40    200    1000   5000    25000    125000
#
# 16   80    400    2000   10000   50000    250000
#
# 32   160   800    4000   20000   100000   500000
#
# 64   320   1600   8000   40000   200000   1000000
