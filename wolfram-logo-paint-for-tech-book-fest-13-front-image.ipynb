# %%
img = Import["https://content.wolfram.com/uploads/sites/10/2016/06/wolfram-language-logo.png"];

# %%
colorLi = { Black, Red, White }
# Out:
# {GrayLevel[0], RGBColor[1, 0, 0], GrayLevel[1]}

# %%
binImgLi = ColorNegate[Binarize[ColorDistance[ImagePad[ImageCrop[img], 5, White], #], 0.5]]& /@ colorLi
# Out:
# {-Image-, -Image-, -Image-}

# %%
Colorize[#, ColorRules -> { 0 -> White, 1 -> Black, 2 -> Blue, 3 -> Red }] & /@ (MorphologicalComponents /@ binImgLi)
# Out:
# {-Image-, -Image-, -Image-}
