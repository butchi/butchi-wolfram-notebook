# %%
Graphics /@ NestList[
    Function[g, GeometricTransformation[g, {
        TranslationTransform[{1, 0}],
        TranslationTransform[{1, 0}],
        TranslationTransform[{1, 0}],
        TranslationTransform[{1, 0}]
    }]],
    Polygon[{
        {0, 0}, {1, 0}, {1, 1}, {0, 1}
    }]
, 3]
# Out:
# {-Graphics-, -Graphics-, -Graphics-, -Graphics-}

# %%
ArrayPlot[#, Frame -> False] & /@ NestList[ArrayFlatten[{{#, #, #}, {#, 0, #}, {#, #, #}}] &, {{1}}, 3]
# Out:
# {-Graphics-, -Graphics-, -Graphics-, -Graphics-}

# %%
ArrayPlot[#, Frame -> False] & /@ NestList[ArrayFlatten[{{#, #, # / 2, #}, {# / 2, 0, 0, #}, {#, 0, 0, # / 2}, {#, # / 2, #, #}}] &, {{1}}, 4]
# Out:
# {-Graphics-, -Graphics-, -Graphics-, -Graphics-, -Graphics-}

# %%
ArrayPlot[#, Frame -> False] & /@ NestList[ArrayFlatten[{{#, 2 # / 3, # / 3, #}, {# / 3, 0, 0, 2 # / 3}, {2 # / 3, 0, 0, # / 3}, {#, # / 3, 2 # / 3, #}}] &, {{1}}, 4]
# Out:
# {-Graphics-, -Graphics-, -Graphics-, -Graphics-, -Graphics-}

# %%
1 - NestList[ImageAssemble[{{#, #}, {#, 0 #}}] &, Image[{{1}}], 5]3
# Out:
# {-Image-, -Image-, -Image-, -Image-, -Image-, -Image-}
