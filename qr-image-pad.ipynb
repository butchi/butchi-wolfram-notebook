# %%
qrImgOrig = Import["https://pbs.twimg.com/media/Ffp-CSHVEAAeKzJ?format=jpg"]
# Out:
# -Image-

# %%
BarcodeRecognize[qrImgOrig]
# Out:
# {}

# %%
qrImg = ImagePad[ImagePad[qrImgOrig, 8, "Fixed"], 15, White]
# Out:
# -Image-

# %%
BarcodeRecognize[qrImg]
# Out:
# (x^2+y^2-2y)(|x^2+y^2+y-16|-y)≦0
