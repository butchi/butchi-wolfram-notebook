# %% [markdown]
# # octaflake-polygon.nb
#
# from octaflake-8-fold.nb
#
# created at 2021-10-27

# %%
tau = Sqrt[2]/2
# Out:
#    1
# -------
# Sqrt[2]

# %%
Table[
    Graphics[{
        {Polygon[ReIm[N[First[#]]]]} & /@ 
            Nest[
                Flatten[
                    Table[
                        polygon /@ (((First /@ # + tau + tau I) E^((2 \[Pi] I (k - 1))/8) + ((1 + tau) + (1 + tau) I))/(2 + Sqrt[2])),
                    {k, 8}]
                ] &, {polygon[{0, 1, 1 + I, I}]},
                n
            ]
    }, ImageSize -> Medium],
{n, 5}]
# Out:
# {-Graphics-, -Graphics-, -Graphics-, -Graphics-, -Graphics-}
