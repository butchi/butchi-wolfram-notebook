# %%
SeedRandom[1];
n = 50;
a = (RandomReal[1, n] E^(I RandomReal[2 \[Pi], n]))/Range[n]^2;
s = (-1)^RandomInteger[1, n];
ListLogPlot[Abs[a]*# & /@ Boole[{Positive[s], Negative[s]}], 
 Filling -> Axis, PlotRange -> All, 
 PlotStyle -> {{Blue, PointSize[Large]}, {Red, PointSize[Large]}}]
f[t_] = Total[a E^(s I Range[n] t)];
ParametricPlot[{Re[#], Im[#]} &[f[t]], {t, 0, 2 \[Pi]}, 
 PlotRange -> All]
# Out:
# -Graphics-
# -Graphics-
