# %% [markdown]
# # graha-fractal-9.nb
#
# from graha-fractal-9-experiment-2020-06-21.nb
#
# from octaflake-8-fold.nb
#
# created at 2021-10-27

# %%
ifs[pLi_] := Flatten[
    Table[
        {(1/(2 + Sqrt[2])) pLi + Sqrt[2]/2 E^((2 \[Pi] I n)/8)} // N,
        {n, 0, 7}
    ]
];

init = {0};

g = Graphics[
    Table[
        Disk[ReIm[#], 1/(1 + Sqrt[2]) (1/(2 + Sqrt[2]))^n // N] & /@ Nest[ifs, init, n],
        {n, 0, 5}
    ]
]

(* Export["graha-fractal-nine.pdf", g] *)
# Out:
# -Graphics-
