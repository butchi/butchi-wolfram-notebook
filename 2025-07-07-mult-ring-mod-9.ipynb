# %%
a0 + a1 * a2

# %%
2^I // N
# Out:
# 0.769239 + 0.638961 I

# %%
Graphics[
    Most @ Table[
        Text[PowerMod[2, i, 9], ReIm[Exp[- 2 Pi I i / 6 - Pi I / 2]]]
    , {i, 0, 6}]
, ImageSize -> Small]
# Out:
# -Graphics-

# %%
Graphics[
    Most @ Table[
        Text[PolynomialMod[Sqrt[2]^i, 9], ReIm[Exp[- 2 Pi I i / 12 - Pi I / 2]]]
    , {i, 0, 12}]
, ImageSize -> Small]
# Out:
# -Graphics-

# %%
Graphics[
    Most @ Table[
        Text[PolynomialMod[Sqrt[5]^i, 9], ReIm[Exp[2 Pi I i / 12 - Pi I / 2]]]
    , {i, 0, 12}]
, ImageSize -> Small]
# Out:
# -Graphics-

# %%
Graphics[
    Most @ Table[
        Text[PolynomialMod[Expand[((1 + Sqrt[5]) / 2)^i], 9], ReIm[Exp[- 2 Pi I i / 24 - Pi I / 2]]]
    , {i, 0, 24}]
]
# Out:
# -Graphics-

# %%
Graphics[
    Most @ Table[
        Text[PolynomialMod[Expand[(1 + Sqrt[2])^i], 9], ReIm[Exp[- 2 Pi I i / 24 - Pi I / 2]]]
    , {i, 0, 24}]
]
# Out:
# -Graphics-

# %%
Graphics[
    Most @ Table[
        Text[PolynomialMod[Expand[((3 + Sqrt[13])/2)^i], 9], ReIm[Exp[- 2 Pi I i / 6 - Pi I / 2]]]
    , {i, 0, 6}]
]
# Out:
# -Graphics-
